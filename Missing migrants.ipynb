# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Migrants = pd.read_csv('./MissingMigrants-Global-2019-12-31_correct.csv', sep = ',')
Migrants
# Out:
#       Web ID Region of Incident      Reported Date  Reported Year  \
# 0      52673      Mediterranean  December 30, 2019           2019
# 1      52666      Mediterranean  December 30, 2019           2019
# 2      52663          East Asia  December 27, 2019           2019
# 3      52662        Middle East  December 26, 2019           2019
# 4      52661        Middle East  December 24, 2019           2019
# ...      ...                ...                ...            ...
# 5982   39207   US-Mexico Border   January 16, 2014           2014
# 5983   39368             Europe   January 16, 2014           2014
# 5984   39257   US-Mexico Border   January 14, 2014           2014
# 5985   39256   US-Mexico Border   January 12, 2014           2014
# 5986   39206   US-Mexico Border   January 06, 2014           2014
#
#      Reported Month  Number Dead  Minimum Estimated Number of Missing  \
# 0               Dec          1.0                                  NaN
# ...

# %%
Migrants.groupby('Cause of Death').count()[['Location Description']]
# Out:
#                                          Location Description
# Cause of Death
# Accident (non-vehicle)                                      3
# Air strike                                                  3
# Asphyxiation                                               11
# Asphyxiation, Drowning                                      2
# Attacked by Apache helicopter                               1
# ...                                                       ...
# Vehicle Accident, Shot, Stabbed                             1
# Violence                                                   50
# Violence while attempting to board boat                     1
# Violence, Asphyxiation, Drowning                            1
# Violence, Rape                                              1
#
# [266 rows x 1 columns]

# %%
Migrants = Migrants[Migrants['Cause of Death']=='Unknown']
Migrants.groupby('Number Dead').count()['Cause of Death']
# Out:
# Number Dead
# 0.0        1
# 1.0      479
# 2.0       37
# 3.0       31
# 4.0       10
# 5.0       10
# 6.0        7
# 7.0        5
# 8.0        9
# 9.0        3
# 10.0       8
# 13.0       3
# 14.0       2
# 15.0       1
# 18.0       2
# 24.0       1
# 36.0       1
# 106.0      1
# Name: Cause of Death, dtype: int64

# %%
Migrants = Migrants[Migrants['Migration Route']=='Central America to US']
Migrants.groupby('Region of Incident').count()['Total Dead and Missing']
# Out:
# Region of Incident
# Central America      20
# US-Mexico Border    262
# Name: Total Dead and Missing, dtype: int64

# %%
deaths = Migrants['Number Dead']
avg = np.round(deaths.mean(),2)
avg
# Out:
# 1.09

# %%
fig, ax = plt.subplots(figsize=(21, 9)) #Subplots makes a call in the background to create a plot area
data = 'MissingMigrants-Global-2019-12-31_correct.csv'
def read_csv(filename):
    with open(filename, 'r') as f:
        data= list(csv.reader(f))
    return data

plt.hist(data, bins = 50, label = 'Missing', color = 'r', alpha = 0.75)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlabel('Value', fontname = 'Sans serif', fontsize = 35)
plt.ylabel('Frequency', fontname = 'Sans serif', fontsize = 35)
plt.legend(loc = 'upper left', fontsize = 30)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

# first subplot
ax1.hist(df[df['Cause of Death']=='Unknown']['Reported Year'],bins=50, label = 'Ages in Cali')
ax1.set_xlabel('Value', fontname='Times New Roman', fontsize = 35)
ax1.set_ylabel('Value', fontname='Times New Roman', fontsize = 35)
ax1.tick_params(axis = 'both', labelsize = 30)
ax1.legend(loc = 'upper left', fontsize = 30)

ax2.hist(df[df['state']=='Colorado']['ages'],bins=50, label = 'Ages in Cali')
ax2.set_xlabel('Value', fontname='Times New Roman', fontsize = 35)
ax2.set_ylabel('Value', fontname='Times New Roman', fontsize = 35)
ax2.tick_params(axis = 'both', labelsize = 30)
ax2.legend(loc = 'upper left', fontsize = 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-2b9c2b67ad3e> in <module>
#       2
#       3 # first subplot
# ----> 4 ax1.hist(df[df['Cause of Death']=='Unknown']['Reported Year'],bins=50, label = 'Ages in Cali')
#       5 ax1.set_xlabel('Value', fontname='Times New Roman', fontsize = 35)
#       6 ax1.set_ylabel('Value', fontname='Times New Roman', fontsize = 35)
#
# NameError: name 'df' is not defined

# %%
demo_outer_surveys.groupby(['city', 'customer_rating']).size()
demo_outer_surveys.groupby(['city', 'customer_rating']).count()
demo_outer_surveys[demo_outer_surveys['customer_rating']=='N/A']['ages'].mean()
from sqlalchemy.types import Integer, Text, String, DateTime, Float
connection = 'postgresql://postgres:Java123!@127.0.0.1:5432/customer_surveys'

demo_outer_surveys.to_sql('customer_surveys_completed', con = connection, if_exists = 'replace', 
                         schema = "public", index = False, chunksize = 300, dtype = {
                             'ages': Integer,
                             'city': String,
                             'customer_id':Integer,
                             'customer_rating': String
                         } )
# databaselanguage(postgresql)://user:password@url:port/database_name
read_from_SQL_DF = pd.read_sql_table('customer_surveys_completed', con = connection)
read_from_SQL_DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-12e39741170f> in <module>
# ----> 1 demo_outer_surveys.groupby(['city', 'customer_rating']).size()
#       2 demo_outer_surveys.groupby(['city', 'customer_rating']).count()
#       3 demo_outer_surveys[demo_outer_surveys['customer_rating']=='N/A']['ages'].mean()
#       4 from sqlalchemy.types import Integer, Text, String, DateTime, Float
#       5 connection = 'postgresql://postgres:Java123!@127.0.0.1:5432/customer_surveys'
#
# NameError: name 'demo_outer_surveys' is not defined
